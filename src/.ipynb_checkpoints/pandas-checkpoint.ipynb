# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 读写
data = pd.read_csv('../dataset/train_folds.csv')
# data.to_pickle('../dataset/train_folds.pickle')

# %%
data = pd.Series(np.random.randn(1000), index=np.arange(1000))
data = data.cumsum()
data.plot()
data.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 4
#       2 data = data.cumsum()
#       3 data.plot()
# ----> 4 data.show()
#
# File E:\compiler\Python39\lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'show'

# %%
data = pd.DataFrame(np.random.randn(1000, 4), index=np.arange(1000), columns=list('ABCD'))
data = data.cumsum()
# bar, hist, box, kde, area, scatter, hexbin, pie
data.plot(ylabel='value', xlabel='time step')
plt.show()

# %%
data = pd.DataFrame(np.random.randn(1000, 4), index=np.arange(1000), columns=list('ABCD'))
data = data.cumsum()
# bar, hist, box, kde, area, scatter, hexbin, pie
ax = data.plot.scatter(x='A', y='B', color='red', label='A vs B')
data.plot.scatter(x='A', y='C', color='green', label='A vs C', ax=ax)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.log(np.maximum(0.01, x))

# %%
plt.figure(num=1, figsize=(8, 6))
plt.plot(x, y1, label='sin', linestyle='--', color='red')
plt.plot(x, y2, label='cos', linewidth=2.0, color='black')
# gca get current axis
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))

plt.legend(loc='best')

X0 = np.pi / 2
y0 = np.sin(X0)

plt.scatter(X0, y0)
plt.plot([X0, X0], [y0, 0], 'k--', lw=1.5)

plt.figure(num=2, figsize=(8, 6))
plt.scatter(x, y3, label='log')
plt.xticks(np.linspace(0, 10, 5))
plt.yticks([-1, 0, 1], ['bad', '$0$', 'good'])

plt.xlim((0, 5))
plt.ylim((-1, 5))

plt.legend(loc='best')
plt.show()

# %%
# bar
import numpy as np
import matplotlib.pyplot as plt

n = 12
X = np.arange(n)
Y1 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)
Y2 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)

plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white')

for x, y in zip(X, Y1):
    # ha: horizontal alignment, va: vertical alignment
    plt.text(x, y + 0.05, '%.2f' % y, ha='center', va='bottom')

for x, y in zip(X, Y2):
    plt.text(x, -y - 0.05, '-%.2f' % y, ha='center', va='top')

plt.xlim(-.5, n)
# plt.xticks(())
plt.ylim(-1.25, +1.25)
# plt.yticks(())
plt.show()

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)
Z = np.sin(np.sqrt(X ** 2 + Y ** 2))
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.get_cmap('rainbow'), edgecolor='k')
ax.contourf(X, Y, Z, zdir='z', offset=-2, cmap=plt.get_cmap('rainbow'))

plt.show()
